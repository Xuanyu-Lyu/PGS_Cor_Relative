# %%
# load dependencies

import os
import sys
import pandas as pd
import numpy as np

# %%
# read the final generation data
data = pd.read_csv('/Users/xuly4739/Library/CloudStorage/OneDrive-UCB-O365/Documents/coding/PyProject/PGS_Cor_Relative/Data/approximation_bi/Condition_01/Iteration_01/iteration_01_phen_gen14.tsv', sep='\t')
# print the variable names
print(data.columns)

# get the correlation between Y1P and Y1M
correlation = data['Y1P'].corr(data['Y1M'])
print(f'Correlation between Y1P and Y1M: {correlation}')
# Out:
# Index(['ID', 'Father.ID', 'Mother.ID', 'Fathers.Father.ID',
#        'Fathers.Mother.ID', 'Mothers.Father.ID', 'Mothers.Mother.ID', 'Sex',
#        'AO_std1', 'AO_std2', 'AL_std1', 'AL_std2', 'AO1', 'AO2', 'AL1', 'AL2',
#        'F1', 'F2', 'E1', 'E2', 'Y1', 'Y2', 'Y1P', 'Y2P', 'Y1M', 'Y2M', 'F1P',
#        'F2P', 'F1M', 'F2M', 'TPO1', 'TPO2', 'TMO1', 'TMO2', 'NTPO1', 'NTPO2',
#        'NTMO1', 'NTMO2', 'TPL1', 'TPL2', 'TML1', 'TML2', 'NTPL1', 'NTPL2',
#        'NTML1', 'NTML2'],
#       dtype='object')
# Correlation between Y1P and Y1M: 0.017328213136244903
